# %%
import getdata
import Model
# Out:
# 2023-07-23 21:30:49.030600: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
data = getdata.get_google_data("Tesla stock", "2023-07-20", "2023-07-23")

# %%
Model.apply_model(data)
# Out:
# {'Positive Percentage': 31.0,
#  'Negative Percentage': 47.0,
#  'Neutral Percentage': 22.0}

# %%
data
# Out:
#                                                 title  \
# 0   Tesla stock is 1,000% overvalued, and its curr...
# 1   Tesla is the next Apple and its valuation coul...
# 2   Tesla is the next Apple and its valuation coul...
# 3   Tesla's Full Self-Driving feature could add $2...
# 4   Dow eyes 9-day win streak as US stocks trade m...
# ..                                                ...
# 95  Elon Musk’s Response to Stock Surge: “Crazy Ti...
# 96  The Bull Market Could Run Another 20% Higher, ...
# 97  Nasdaq slips, Dow ekes out 10th day of gains: ...
# 98  Threat or not? Elon Musk gets new hearing on t...
# 99  Tesla Cybertruck demand ‘so far off the hook, ...
#
#                                           description  \
# 0   One analyst says the carmaker's true value lie...
# 1   Shares in Elon Musk's EV maker could hit $350,...
# 2   Shares in Elon Musk's EV maker could hit $350,...
# 3   Elon Musk confirmed Tesla was in talks with a ...
# ...
